# %% [markdown]
#  # Reading an image file and converting it to a numpy array

# %%
import requests
url = 'https://images.pexels.com/photos/106399/pexels-photo-106399.jpeg'
response = requests.get(url)

# %%
# Check if the request was successful

if response.status_code == 200:
    with open('image.jpg', 'wb') as f:
        f.write(response.content)
    print('Image downloaded successfully.')
else:
    print(f'Failed to download image. Status code: {response.status_code}')
# Out:
# Image downloaded successfully.

# %%
from IPython.display import Image
# The Path to the image file
image_path = 'image.jpg'
# Displaying the image
Image(filename=image_path)

# %%
# importing the image module from matplotlib library
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread('image.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (3605, 5408, 3)

# %%
print(img)
# Out:
# [[[156 178 219]
#   [156 178 219]
#   [156 178 219]
#   ...
#   [137 164 219]
#   [137 164 219]
#   [137 164 219]]
#
#  [[156 178 219]
#   [156 178 219]
#   [156 178 219]
#   ...
#   [137 164 219]
#   [137 164 219]
#   [137 164 219]]
#
#  [[156 178 219]
#   [156 178 219]
#   [156 178 219]
#   ...
#   [137 164 219]
#   [137 164 219]
#   [137 164 219]]
#
#  ...
#
#  [[255 250 254]
#   [255 250 254]
#   [254 249 253]
#   ...
#   [185 191 225]
#   [183 189 223]
#   [181 187 221]]
#
#  [[255 250 254]
#   [255 250 254]
#   [254 249 253]
#   ...
#   [188 194 228]
#   [184 190 224]
#   [182 188 222]]
#
#  [[255 250 254]
#   [255 250 254]
#   [254 249 253]
#   ...
#   [191 197 231]
#   [188 194 228]
#   [187 193 227]]]

# %%
# Displaying the image from numpy array
img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# # Resizing an image using pillow library

# %%
from PIL import  Image

# %%
img = Image.open('image.jpg')
img_resized=img.resize((200,200))

# %%
img_resized.save('image_resized.jpg')

# %%
# Displaying the image from numpy array

img_res=mpimg.imread('image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# # RGB to Grayscale conversion using OpenCV

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\91967\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\91967\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opencv-python) (2.1.3)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\91967\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
#importing open cv library

import cv2

# %%
img =cv2.imread('image.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (3605, 5408, 3)

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (3605, 5408)

# %%
import matplotlib.pyplot as plt
import cv2

# Loading RGB image
img_rgb = cv2.imread('image.jpg')

# Converting RGB to grayscale
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)

# Displaying grayscale image using matplotlib
plt.imshow(img_gray, cmap='gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(5407.5), np.float64(3604.5), np.float64(-0.5))

# %%
cv2.imwrite('image_gray.jpg', img_gray)
# Out:
# True

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image in grayscale
img_gray = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)

# Check if the image was loaded correctly
if img_gray is not None:
    # Display the image using matplotlib
    plt.imshow(img_gray, cmap='gray')
    plt.axis('off')  # Hide axis for a cleaner look
    plt.show()
else:
    print("Failed to load image.")
